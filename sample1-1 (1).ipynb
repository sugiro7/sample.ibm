# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Yu Osugi**

# %% [markdown]
# *I am interested in data science because　data enhance the business*

# %% [markdown]
# ### The following code is "if-syntax"

# %%
x = 21
y = 20
if x + y < 40:
    print("False")
else:
    print("True")
# Out:
# True

# %% [markdown]
# <ul>
# <li>one</li>
# <li>two</li>
# <li>three</li>
# <li>four</li>
# <li>five</li>
# <li>six</li>
# </ul>

# %% [markdown]
# <img src="https://1.bp.blogspot.com/-oXwuogun7bU/X5OchgTAKeI/AAAAAAABcAA/Ul9NNX7jp7k2fJIrdbbTJDn9ZkgwF1ozgCNcBGAsYHQ/s876/sports_referee_var_pose.png" alt="VAR">

# %% [markdown]
# <a href = "https://www.ibm.com/jp-ja">IBM home page</a>
